# %% [markdown]
# <a href="https://colab.research.google.com/github/mitpalorg/police-accountability-lab/blob/master/r_propub_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
propub <- read.csv(url("https://raw.githubusercontent.com/mitpalorg/police-accountability-lab/master/allegations_20200726939.csv"))

# %%
head(propub)
# Out:
#   unique_mos_id first_name last_name command_now complaint_id month_received
# 1 10004         Jonathan   Ruiz      078 PCT     42835         7
# 2 10007         John       Sears     078 PCT     24601        11
# 3 10007         John       Sears     078 PCT     24601        11
# 4 10007         John       Sears     078 PCT     26146         7
# 5 10009         Noemi      Sierra    078 PCT     40253         8
# 6 10012         Paula      Smith     078 PCT     37256         5
#   year_received month_closed year_closed command_at_incident ⋯ mos_age_incident
# 1 2019           5           2020        078 PCT             ⋯ 32
# 2 2011           8           2012        PBBS                ⋯ 24
# 3 2011           8           2012        PBBS                ⋯ 24
# 4 2012           9           2013        PBBS                ⋯ 25
# 5 2018           2           2019        078 PCT             ⋯ 39
# 6 2017          10           2017        078 PCT             ⋯ 50
#   complainant_ethnicity complainant_gender complainant_age_incident
# 1 Black                 Female             38
# 2 Black                 Male               26
# 3 Black                 Male               26
# 4 Black                 Male               45
# 5                                          16
# 6 White                 Male               31
#   fado_type          allegation                            precinct
# 1 Abuse of Authority Failure to provide RTKA card          78
# 2 Discourtesy        Action                                67
# 3 Offensive Language Race                                  67
# 4 Abuse of Authority Question                              67
# 5 Force              Physical force                        67
# 6 Abuse of Authority Refusal to process civilian complaint 78
#   contact_reason                               outcome_description
# 1 Report-domestic dispute                      No arrest made or summons issued
# 2 Moving violation                             Moving violation summons issued
# 3 Moving violation                             Moving violation summons issued
# 4 PD suspected C/V of violation/crime - street No arrest made or summons issued
# 5 Report-dispute                               Arrest - other violation/crime
# 6 C/V telephoned PCT                           No arrest made or summons issued
#   board_disposition
# 1 Substantiated (Command Lvl Instructions)
# 2 Substantiated (Charges)
# 3 Substantiated (Charges)
# 4 Substantiated (Charges)
# 5 Substantiated (Command Discipline A)
# 6 Substantiated (Command Lvl Instructions)

# %%
a <- propub[,'unique_mos_id']
plot(ecdf(a), main=NA)
# Out:
# Plot with title “NA”

# %%
library(tidyverse)
b <- propub %>% filter(fado_type=='Force') %>%
             select(unique_mos_id)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.3.2     ✔ purrr   0.3.4
# ✔ tibble  3.0.2     ✔ dplyr   1.0.0
# ✔ tidyr   1.1.0     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.5.0
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
c <- data.frame(cbind( Freq=table(b), Cumul=cumsum(table(b)), relative=prop.table(table(b))))

# %%
library(ggplot2)
#ggplot(data = data.frame(c$Cumul)) + geom_point()

plot(ecdf(c$Cumul), main=NA)
# Out:
# Plot with title “NA”

# %%
c
# Out:
#       Freq Cumul relative
# 5     1     1    0.0001309586
# 11    2     3    0.0002619172
# 21    1     4    0.0001309586
# 23    4     8    0.0005238345
# 38    2    10    0.0002619172
# 43    2    12    0.0002619172
# 73    2    14    0.0002619172
# 83    2    16    0.0002619172
# 110   7    23    0.0009167103
# 196   1    24    0.0001309586
# 200   2    26    0.0002619172
# 202   5    31    0.0006547931
# 203   2    33    0.0002619172
# 208   2    35    0.0002619172
# 219   2    37    0.0002619172
# 220   1    38    0.0001309586
# 223   1    39    0.0001309586
# 274   1    40    0.0001309586
# 283   2    42    0.0002619172
# 295   2    44    0.0002619172
# 319   3    47    0.0003928759
# 349   2    49    0.0002619172
# 380   7    56    0.0009167103
# 422   2    58    0.0002619172
# 454   2    60    0.0002619172
# 462   1    61    0.0001309586
# 483   3    64    0.0003928759
# 559   3    67    0.0003928759
# 576   1    68    0.0001309586
# 613   1    69    0.0001309586
# ⋮     ⋮    ⋮     ⋮
# 36023 4    7547  0.0005238345
# 36034 1    7548  0.0001309586
# 36035 7    7555  0.0009167103
# 36047 2    7557  0.0002619172
# 36049 3    7560  0.0003928759
# 36051 1    7561  0.0001309586
# 36055 2    7563  0.0002619172
# 36057 6    7569  0.0007857517
# 36061 1    7570  0.0001309586
# 36063 3    7573  0.0003928759
# 36065 5    7578  0.0006547931
# 36078 1    7579  0.0001309586
# 36082 3    7582  0.0003928759
# 36091 3    7585  0.0003928759
# 36101 2    7587  0.0002619172
# 36103 4    7591  0.0005238345
# 36131 2    7593  0.0002619172
# 36140 3    7596  0.0003928759
# 36141 2    7598  0.0002619172
# 36143 3    7601  0.0003928759
# 36149 2    7603  0.0002619172
# 36152 5    7608  0.0006547931
# 36154 1    7609  0.0001309586
# 36155 2    7611  0.0002619172
# 36158 2    7613  0.0002619172
# 36167 5    7618  0.0006547931
# 36233 5    7623  0.0006547931
# 36247 9    7632  0.0011786276
# 36248 1    7633  0.0001309586
# 36374 3    7636  0.0003928759

# %%
d <- propub %>% filter(fado_type=='Force')

options(repr.plot.width = 12, repr.plot.height = 10)
g <- ggplot(d, aes(mos_age_incident, complainant_age_incident, col=complainant_ethnicity))
g + geom_jitter(width = .5, size=.5) +
  labs(subtitle="Maturity? Complainant v. Officer Age", 
       y="Complainant", 
       x="Officer", 
       title="Jittered Points")
# Out:
# Warning message:
# “Removed 917 rows containing missing values (geom_point).”
# plot without title

# %%
var <- d$board_disposition  # the categorical data 

## Prep data (nothing to change here)
nrows <- 10
df <- expand.grid(y = 1:nrows, x = 1:nrows)
categ_table <- round(table(var) * ((nrows*nrows)/(length(var))))
categ_table
# Out:
# var
#                               Exonerated
#                                       46
#                  Substantiated (Charges)
#                                        8
#     Substantiated (Command Discipline A)
#                                        1
#     Substantiated (Command Discipline B)
#                                        1
#       Substantiated (Command Discipline)
#                                        1
# Substantiated (Command Lvl Instructions)
#                                        0
#      Substantiated (Formalized Training)
#                                        1
#             Substantiated (Instructions)
#                                        0
#         Substantiated (MOS Unidentified)
#                                        0
#       Substantiated (No Recommendations)
#                                        1
#                          Unsubstantiated
#                                       41

# %%
df$category <- factor(rep(names(categ_table), categ_table))  
# NOTE: if sum(categ_table) is not 100 (i.e. nrows^2), it will need adjustment to make the sum to 100.

## Plot
ggplot(df, aes(x = df$x, y = df$y, fill = category)) + 
        geom_tile(color = "black", size = 0.5) +
        scale_x_continuous(expand = c(0, 0)) +
        scale_y_continuous(expand = c(0, 0), trans = 'reverse') +
        scale_fill_brewer(palette = "Set3") +
        labs(title="Waffle Chart", subtitle="'Class' of vehicles",
             caption="Source: mpg") + 
        theme(panel.border = element_rect(size = 2),
              plot.title = element_text(size = rel(1.2)),
              axis.text = element_blank(),
              axis.title = element_blank(),
              axis.ticks = element_blank(),
              legend.title = element_blank(),
              legend.position = "right")
# Out:
# plot without title

# %%
library(plyr)
library(scales)
library(zoo)

df <- read.csv("https://raw.githubusercontent.com/selva86/datasets/master/yahoo.csv")
df$date <- as.Date(df$date)  # format date
df <- df[df$year >= 2012, ]  # filter reqd years

# Create Month Week
df$yearmonth <- as.yearmon(df$date)
df$yearmonthf <- factor(df$yearmonth)
df <- ddply(df,.(yearmonthf), transform, monthweek=1+week-min(week))  # compute week number of month
df <- df[, c("year", "yearmonthf", "monthf", "week", "monthweek", "weekdayf", "VIX.Close")]
head(df)
#>   year yearmonthf monthf week monthweek weekdayf VIX.Close
#> 1 2012   Jan 2012    Jan    1         1      Tue     22.97
#> 2 2012   Jan 2012    Jan    1         1      Wed     22.22
#> 3 2012   Jan 2012    Jan    1         1      Thu     21.48
#> 4 2012   Jan 2012    Jan    1         1      Fri     20.63
#> 5 2012   Jan 2012    Jan    2         2      Mon     21.07
#> 6 2012   Jan 2012    Jan    2         2      Tue     20.69


# Plot
ggplot(df, aes(monthweek, weekdayf, fill = VIX.Close)) + 
  geom_tile(colour = "white") + 
  facet_grid(year~monthf) + 
  scale_fill_gradient(low="red", high="green") +
  labs(x="Week of Month",
       y="",
       title = "Time-Series Calendar Heatmap", 
       subtitle="Yahoo Closing Price", 
       fill="Close")
# Out:
# Error in library(waffle): there is no package called ‘waffle’
# Traceback:
#
# 1. library(waffle)

# %%
install.packages("ggmap", repos = "http://cran.rstudio.com/")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘sp’, ‘RgoogleMaps’, ‘png’, ‘plyr’, ‘rjson’, ‘jpeg’, ‘bitops’

# %%
devtools::install_github("hrbrmstr/ggalt")
install.packages("waffle", repos = "https://cinc.rud.is")
# Out:
# Downloading GitHub repo hrbrmstr/ggalt@master
# proj4     (NA    -> 1.0-10) [CRAN]
# tibble    (3.0.2 -> 3.0.3 ) [CRAN]
# pkgbuild  (1.0.8 -> 1.1.0 ) [CRAN]
# rprojroot (1.2   -> 1.3-2 ) [CRAN]
# farver    (2.0.1 -> 2.0.3 ) [CRAN]
# pillar    (1.4.5 -> 1.4.6 ) [CRAN]
# vctrs     (0.3.1 -> 0.3.2 ) [CRAN]
# curl      (4.2   -> 4.3   ) [CRAN]
# sys       (3.3   -> 3.4   ) [CRAN]
# httr      (1.4.1 -> 1.4.2 ) [CRAN]
# Installing 10 packages: proj4, tibble, pkgbuild, rprojroot, farver, pillar, vctrs, curl, sys, httr
#
# Installing packages into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
# Error: Failed to install 'ggalt' from GitHub:
#   (converted from warning) installation of package ‘proj4’ had non-zero exit status
# Traceback:
#
# 1. devtools::install_github("hrbrmstr/ggalt")
# 2. pkgbuild::with_build_tools({
#  .     ellipsis::check_dots_used(action = getOption("devtools.ellipsis_action",
#  .         rlang::warn))
#  .     {
#  .         remotes <- lapply(repo, github_remote, ref = ref, subdir = subdir,
#  .             auth_token = auth_token, host = host)
#  .         install_remotes(remotes, auth_token = auth_token, host = host,
#  .             dependencies = dependencies, upgrade = upgrade, force = force,
#  .             quiet = quiet, build = build, build_opts = build_opts,
#  .             build_manual = build_manual, build_vignettes = build_vignettes,
#  .             repos = repos, type = type, ...)
#  .     }
#  . }, required = FALSE)
# 3. install_remotes(remotes, auth_token = auth_token, host = host,
#  .     dependencies = dependencies, upgrade = upgrade, force = force,
#  .     quiet = quiet, build = build, build_opts = build_opts, build_manual = build_manual,
#  .     build_vignettes = build_vignettes, repos = repos, type = type,
#  .     ...)
# 4. tryCatch(res[[i]] <- install_remote(remotes[[i]], ...), error = function(e) {
#  .     stop(remote_install_error(remotes[[i]], e))
#  . })
# 5. tryCatchList(expr, classes, parentenv, handlers)
# 6. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 7. value[[3L]](cond)

# %%
library(ggmap)
library(ggalt)
# Out:
# Error in library(ggalt): there is no package called ‘ggalt’
# Traceback:
#
# 1. library(ggalt)

# %%
chennai <-  geocode("Chennai")  # get longitude and latitude

# Get the Map ----------------------------------------------
# Google Satellite Map
chennai_ggl_sat_map <- qmap("chennai", zoom=12, source = "google", maptype="satellite")  

# Google Road Map
chennai_ggl_road_map <- qmap("chennai", zoom=12, source = "google", maptype="roadmap")  

# Google Hybrid Map
chennai_ggl_hybrid_map <- qmap("chennai", zoom=12, source = "google", maptype="hybrid")  

# Open Street Map
chennai_osm_map <- qmap("chennai", zoom=12, source = "osm")   

# Get Coordinates for Chennai's Places ---------------------
chennai_places <- c("Kolathur",
                    "Washermanpet",
                    "Royapettah",
                    "Adyar",
                    "Guindy")

places_loc <- geocode(chennai_places)  # get longitudes and latitudes




# Google Hybrid Map ----------------------------------------
chennai_ggl_hybrid_map + geom_point(aes(x=lon, y=lat),
                                     data = places_loc, 
                                     alpha = 0.7, 
                                     size = 7, 
                                     color = "tomato") + 
                          geom_encircle(aes(x=lon, y=lat),
                                        data = places_loc, size = 2, color = "blue")
# Out:
# Error: Google now requires an API key.
#        See ?register_google for details.
# Traceback:
#
# 1. geocode("Chennai")
# 2. stop("Google now requires an API key.", "\n       See ?register_google for details.",
#  .     call. = FALSE)
